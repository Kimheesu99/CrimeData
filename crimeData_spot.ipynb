# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
import matplotlib.ticker as mticker

df1 = pd.read_csv('spot.csv')
df1.head()


df1.tail()
df1.info()
df1.index
df1.columns
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28 entries, 0 to 27
# Data columns (total 28 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   범죄분류        28 non-null     object
#  1   아파트_연립_다세대  28 non-null     int64
#  2   단독주택        28 non-null     int64
#  3   고속도로        28 non-null     int64
#  4   노상          28 non-null     int64
#  5   상점          28 non-null     int64
#  6   시장노점        28 non-null     int64
#  7   숙박업소_목욕탕    28 non-null     int64
#  8   유흥접객업소      28 non-null     int64
#  9   사무실         28 non-null     int64
#  10  공장          28 non-null     int64
#  11  공사장_광산      28 non-null     int64
#  12  창고          28 non-null     int64
#  13  역대합실        28 non-null     int64
#  14  지하철         28 non-null     int64
#  15  기타교통수단내     28 non-null     int64
#  16  흥행장         28 non-null     int64
#  17  유원지         28 non-null     int64
#  18  학교          28 non-null     int64
# ...

# %%
df1['범죄분류'].unique()
df1.groupby(['범죄분류']).count()
# Out:
#                        아파트_연립_다세대  단독주택  고속도로  노상  상점  시장노점  숙박업소_목욕탕  유흥접객업소  \
# 범죄분류
# 강도                              1     1     1   1   1     1         1       1
# 경범죄처벌법                          1     1     1   1   1     1         1       1
# 공갈                              1     1     1   1   1     1         1       1
# 과실치사상                           1     1     1   1   1     1         1       1
# 도박과 복표                          1     1     1   1   1     1         1       1
# 마약류관리에관한법률(대마)                  1     1     1   1   1     1         1       1
# 마약류관리에관한법률(마약)                  1     1     1   1   1     1         1       1
# 마약류관리에관한법률(향정)                  1     1     1   1   1     1         1       1
# 방화                              1     1     1   1   1     1         1       1
# 살인                              1     1     1   1   1     1         1       1
# 상해                              1     1     1   1   1     1         1       1
# ...

# %%
# 열 합계 계산
df1_group = df1.sum()
df1_group

#기타 부분 제외하고, 각 지역 별 범죄 횟수 값 df_new에 저장
df_new = df1_group[1:-1]
df_new
# Out:
# 아파트_연립_다세대     38513
# 단독주택           34692
# 고속도로             528
# 노상            154083
# 상점             26529
# 시장노점            3668
# 숙박업소_목욕탕       12939
# 유흥접객업소         37732
# 사무실            14504
# 공장              2831
# 공사장_광산          2899
# 창고              1287
# 역대합실            3597
# 지하철             2596
# 기타교통수단내         3909
# 흥행장              769
# 유원지             3705
# 학교              3305
# 금융기관            4598
# 의료기관            4250
# 종교기관            1922
# 산야              4540
# 해상               577
# 부대                90
# 구금장소             360
# 공지                77
# dtype: object

# %%
df_new[25]

x = np.arange(26)

local = df_new.index
count = []

count.append(df_new[0])
count.append(df_new[1])
count.append(df_new[2])
count.append(df_new[3])
count.append(df_new[4])
count.append(df_new[5])
count.append(df_new[6])
count.append(df_new[7])
count.append(df_new[8])
count.append(df_new[9])
count.append(df_new[10])
count.append(df_new[11])
count.append(df_new[12])
count.append(df_new[13])
count.append(df_new[14])
count.append(df_new[15])
count.append(df_new[16])
count.append(df_new[17])
count.append(df_new[18])
count.append(df_new[19])
count.append(df_new[20])
count.append(df_new[21])
count.append(df_new[22])
count.append(df_new[23])
count.append(df_new[24])
count.append(df_new[25])

plt.rc('font', family='Malgun Gothic')
plt.figure(figsize=(30,15))
bar = plt.bar(local, count, color = ['gold', 'gold', 'gold', 'blue', 'gold', 'gold', 'gold', 'gold', 'gold', 
                                     'gold', 'gold', 'gold', 'gold', 'gold', 'gold', 'gold', 'gold', 'gold',
                                     'gold', 'gold', 'gold', 'gold', 'gold', 'gold', 'gold', 'gold'], alpha = 0.9)
plt.ylim([0, 170000])     # Y축의 범위: [ymin, ymax]

plt.gca().yaxis.set_major_formatter(mticker.FormatStrFormatter('%d회'))

ax = plt.subplot(1, 1, 1)
for label in ax.xaxis.get_ticklabels() :
    label.set_rotation(65)
    
for rect in bar:
    height = rect.get_height()
    plt.text(rect.get_x() + rect.get_width()/2.0, height, '%d' % height, ha='center', va='bottom', size = 12, color = 'gray')
    
plt.tick_params(axis='x', direction='in', length=3, pad=6, labelsize=14, labelcolor='black', top=True)
plt.tick_params(axis='y', direction='inout', length=10, pad=15, labelsize=12, width=2, color='black')


plt.title('\n<장소별 범죄 발생 횟수>\n', fontsize=30)
plt.xlabel('\n장소', fontsize=20)
plt.ylabel('횟수\n', fontsize=20)

plt.show()
