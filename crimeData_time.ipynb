# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
import matplotlib.ticker as mticker

df1 = pd.read_csv('time.csv')
df1.head()


df1.tail()
df1.info()
df1.index
df1.columns
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31 entries, 0 to 30
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   범죄분류           31 non-null     object
#  1   00시00분-02시59분  31 non-null     int64
#  2   03시00분-05시59분  31 non-null     int64
#  3   06시00분-08시59분  31 non-null     int64
#  4   09시00분-11시59분  31 non-null     int64
#  5   12시00분-14시59분  31 non-null     int64
#  6   15시00분-17시59분  31 non-null     int64
#  7   18시00분-20시59분  31 non-null     int64
#  8   21시00분-23시59분  31 non-null     int64
#  9   미상             31 non-null     int64
# dtypes: int64(9), object(1)
# memory usage: 2.5+ KB
# Index(['범죄분류', '00시00분-02시59분', '03시00분-05시59분', '06시00분-08시59분',
#        '09시00분-11시59분', '12시00분-14시59분', '15시00분-17시59분', '18시00분-20시59분',
#        '21시00분-23시59분', '미상'],
#       dtype='object')

# %%
df1['범죄분류'].unique()
df1.groupby(['범죄분류']).count()
# Out:
#                        00시00분-02시59분  03시00분-05시59분  06시00분-08시59분  \
# 범죄분류
# 가정폭력범죄의처벌등에관한특례법                   1              1              1
# 강도                                 1              1              1
# 경범죄처벌법                             1              1              1
# 공갈                                 1              1              1
# 과실치사상                              1              1              1
# 교통사고처리특례법                          1              1              1
# 도로교통법                              1              1              1
# 도로교통법(무면허운전)                       1              1              1
# 도로교통법(사고후미조치)                      1              1              1
# 도로교통법(음주운전)                        1              1              1
# 도로교통법(음주측정거부)                      1              1              1
# 도박과복표                              1              1              1
# 마약류관리에관한법률(대마)                     1              1              1
# 마약류관리에관한법률(마약)                     1              1              1
# 마약류관리에관한법률(향정)                     1              1              1
# 방화                                 1              1              1
# 살인                                 1              1              1
# 상해                                 1              1              1
# 성매매알선등행위의처벌에관한법률                   1              1              1
# 성폭력                                1              1              1
# 아동·청소년의성보호에관한법률(성매수등)              1              1              1
# 아동·청소년의성보호에관한법률(음란물등)              1              1              1
# 약취와유인                              1              1              1
# 업무상과실치사상                           1              1              1
# 절도                                 1              1              1
# 체포와감금                              1              1              1
# 특가법(도주차량)                          1              1              1
# 폭력행위등(단체등의구성·활동)                   1              1              1
# 폭력행위등(손괴·강요·주거침입등)                 1              1              1
# 폭행                                 1              1              1
# 협박                                 1              1              1
#
#                        09시00분-11시59분  12시00분-14시59분  15시00분-17시59분  \
# 범죄분류
# 가정폭력범죄의처벌등에관한특례법                   1              1              1
# 강도                                 1              1              1
# 경범죄처벌법                             1              1              1
# 공갈                                 1              1              1
# 과실치사상                              1              1              1
# 교통사고처리특례법                          1              1              1
# 도로교통법                              1              1              1
# 도로교통법(무면허운전)                       1              1              1
# 도로교통법(사고후미조치)                      1              1              1
# 도로교통법(음주운전)                        1              1              1
# 도로교통법(음주측정거부)                      1              1              1
# 도박과복표                              1              1              1
# 마약류관리에관한법률(대마)                     1              1              1
# 마약류관리에관한법률(마약)                     1              1              1
# 마약류관리에관한법률(향정)                     1              1              1
# 방화                                 1              1              1
# 살인                                 1              1              1
# 상해                                 1              1              1
# 성매매알선등행위의처벌에관한법률                   1              1              1
# 성폭력                                1              1              1
# 아동·청소년의성보호에관한법률(성매수등)              1              1              1
# 아동·청소년의성보호에관한법률(음란물등)              1              1              1
# 약취와유인                              1              1              1
# 업무상과실치사상                           1              1              1
# 절도                                 1              1              1
# 체포와감금                              1              1              1
# 특가법(도주차량)                          1              1              1
# 폭력행위등(단체등의구성·활동)                   1              1              1
# 폭력행위등(손괴·강요·주거침입등)                 1              1              1
# 폭행                                 1              1              1
# 협박                                 1              1              1
#
#                        18시00분-20시59분  21시00분-23시59분  미상
# 범죄분류
# 가정폭력범죄의처벌등에관한특례법                   1              1   1
# 강도                                 1              1   1
# 경범죄처벌법                             1              1   1
# 공갈                                 1              1   1
# 과실치사상                              1              1   1
# 교통사고처리특례법                          1              1   1
# 도로교통법                              1              1   1
# 도로교통법(무면허운전)                       1              1   1
# 도로교통법(사고후미조치)                      1              1   1
# 도로교통법(음주운전)                        1              1   1
# 도로교통법(음주측정거부)                      1              1   1
# 도박과복표                              1              1   1
# 마약류관리에관한법률(대마)                     1              1   1
# 마약류관리에관한법률(마약)                     1              1   1
# 마약류관리에관한법률(향정)                     1              1   1
# 방화                                 1              1   1
# 살인                                 1              1   1
# 상해                                 1              1   1
# 성매매알선등행위의처벌에관한법률                   1              1   1
# 성폭력                                1              1   1
# 아동·청소년의성보호에관한법률(성매수등)              1              1   1
# 아동·청소년의성보호에관한법률(음란물등)              1              1   1
# 약취와유인                              1              1   1
# 업무상과실치사상                           1              1   1
# 절도                                 1              1   1
# 체포와감금                              1              1   1
# 특가법(도주차량)                          1              1   1
# 폭력행위등(단체등의구성·활동)                   1              1   1
# 폭력행위등(손괴·강요·주거침입등)                 1              1   1
# 폭행                                 1              1   1
# 협박                                 1              1   1

# %%
df1_group = df1.groupby('범죄분류').sum()
df1_group
# Out:
#                        00시00분-02시59분  03시00분-05시59분  06시00분-08시59분  \
# 범죄분류
# 가정폭력범죄의처벌등에관한특례법                   7             10             10
# 강도                               132            162             58
# 경범죄처벌법                           941            877            343
# 공갈                               187            133            103
# 과실치사상                            108            108            166
# 교통사고처리특례법                       5928           7054          21565
# 도로교통법                            636            715           1730
# 도로교통법(무면허운전)                    1473           1489           3555
# 도로교통법(사고후미조치)                   2621           2735           5437
# 도로교통법(음주운전)                    23460          19137          10839
# 도로교통법(음주측정거부)                    506            372            138
# 도박과복표                            272            176            219
# 마약류관리에관한법률(대마)                    45             35             12
# 마약류관리에관한법률(마약)                     1              6             16
# 마약류관리에관한법률(향정)                   316            202            161
# 방화                               157            140             82
# 살인                                67             69             75
# 상해                              6052           5170           2995
# 성매매알선등행위의처벌에관한법률                 587            389            120
# 성폭력                             3200           3296           2615
# 아동·청소년의성보호에관한법률(성매수등)             29             33             22
# 아동·청소년의성보호에관한법률(음란물등)             12             14             12
# 약취와유인                             12             11             13
# 업무상과실치사상                          54             90            314
# 절도                             13751          14385          12502
# 체포와감금                            120            137            138
# 특가법(도주차량)                        358            333            507
# 폭력행위등(단체등의구성·활동)                   5             13              4
# 폭력행위등(손괴·강요·주거침입등)                82             71             49
# 폭행                             22343          18552           9738
# 협박                              1011            777           1108
#
#                        09시00분-11시59분  12시00분-14시59분  15시00분-17시59분  \
# 범죄분류
# 가정폭력범죄의처벌등에관한특례법                  19             19             25
# 강도                                72             77             90
# 경범죄처벌법                           397            368            523
# 공갈                               486            365            553
# 과실치사상                            315            374            473
# 교통사고처리특례법                      26810          29156          33739
# 도로교통법                           2993           2763           3543
# 도로교통법(무면허운전)                   10444           7173          10843
# 도로교통법(사고후미조치)                   6759           6948           7657
# 도로교통법(음주운전)                     5052           4138           5782
# 도로교통법(음주측정거부)                     84            104            155
# 도박과복표                            701            667            994
# 마약류관리에관한법률(대마)                   158             82            124
# 마약류관리에관한법률(마약)                   275            272            298
# 마약류관리에관한법률(향정)                   733            544            618
# 방화                               113            156            149
# 살인                                94             88            100
# 상해                              3895           3781           4606
# 성매매알선등행위의처벌에관한법률                 447            839           1652
# 성폭력                             2559           2651           3442
# 아동·청소년의성보호에관한법률(성매수등)             58             76            131
# 아동·청소년의성보호에관한법률(음란물등)             41             34             37
# 약취와유인                             29             30             41
# 업무상과실치사상                         881            661            606
# 절도                             21531          24623          26890
# 체포와감금                            206            183            181
# 특가법(도주차량)                        368            502            669
# 폭력행위등(단체등의구성·활동)                   4              7              7
# 폭력행위등(손괴·강요·주거침입등)               106             92             82
# 폭행                             11575          11798          14291
# 협박                              1857           1777           1982
#
#                        18시00분-20시59분  21시00분-23시59분     미상
# 범죄분류
# 가정폭력범죄의처벌등에관한특례법                  44             46     17
# 강도                               100            136    163
# 경범죄처벌법                           731           1474    837
# 공갈                               733            673   1748
# 과실치사상                            358            336    345
# 교통사고처리특례법                      34814          21740   4703
# 도로교통법                           2415           1800    670
# 도로교통법(무면허운전)                    5876           5203   1031
# 도로교통법(사고후미조치)                   8828           7275   1987
# 도로교통법(음주운전)                    16269          72175  21841
# 도로교통법(음주측정거부)                    299            837    310
# 도박과복표                           1243           1129   3398
# 마약류관리에관한법률(대마)                   130            139    362
# 마약류관리에관한법률(마약)                    55             14    368
# 마약류관리에관한법률(향정)                   937            782   2505
# 방화                               197            248    116
# 살인                               126            141     98
# 상해                              6178          10129   6570
# 성매매알선등행위의처벌에관한법률                1914           2692   1775
# 성폭력                             4335           5303   5423
# 아동·청소년의성보호에관한법률(성매수등)            115             93    188
# 아동·청소년의성보호에관한법률(음란물등)             22             24    295
# 약취와유인                             30              5     45
# 업무상과실치사상                         218            116    545
# 절도                             26654          22167  21852
# 체포와감금                            228            246    289
# 특가법(도주차량)                        859            960    255
# 폭력행위등(단체등의구성·활동)                  17             14     69
# 폭력행위등(손괴·강요·주거침입등)                90             95    176
# 폭행                             21375          38210  17616
# 협박                              2424           2590   2481

# %%
# 열 합계 계산
df1_group = df1.sum()
df1_group

df_new = df1_group[1:]
df_new
# Out:
# 00시00분-02시59분     84473
# 03시00분-05시59분     76691
# 06시00분-08시59분     74646
# 09시00분-11시59분     99062
# 12시00분-14시59분    100348
# 15시00분-17시59분    120283
# 18시00분-20시59분    137614
# 21시00분-23시59분    196792
# 미상                98078
# dtype: object

# %%
df_new[8]

x = np.arange(9)

time = df_new.index
count = []

count.append(df_new[0])
count.append(df_new[1])
count.append(df_new[2])
count.append(df_new[3])
count.append(df_new[4])
count.append(df_new[5])
count.append(df_new[6])
count.append(df_new[7])
count.append(df_new[8])

plt.rc('font', family='Malgun Gothic')
plt.figure(figsize=(15,8))
bar = plt.bar(time, count, color = ['gold', 'gold', 'gold', 'gold', 'gold', 'gold', 'gold', 'blue', 'gold'], alpha = 0.9)
plt.ylim([0, 250000])     # Y축의 범위: [ymin, ymax]

plt.gca().yaxis.set_major_formatter(mticker.FormatStrFormatter('%d회'))

ax = plt.subplot(1, 1, 1)
for label in ax.xaxis.get_ticklabels() :
    label.set_rotation(55)
    
for rect in bar:
    height = rect.get_height()
    plt.text(rect.get_x() + rect.get_width()/2.0, height, '%d' % height, ha='center', va='bottom', size = 12, color = 'gray')
    
plt.tick_params(axis='x', direction='in', length=3, pad=6, labelsize=14, labelcolor='black', top=True)
plt.tick_params(axis='y', direction='inout', length=10, pad=15, labelsize=12, width=2, color='black')

    
plt.title('\n<시간대별 범죄 발생 횟수>\n', fontsize=30)
plt.xlabel('\n시간대', fontsize=20)
plt.ylabel('횟수\n', fontsize=20)

plt.show()
